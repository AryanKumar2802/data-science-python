# %%
def any_info(name,system_id):
  print("Name of the student ",name,"and the systemid: ",system_id)

# %%
any_info("ashwini",2023416075)
# Out:
# Name of the student  ashwini and the systemid  2023416075

# %%
any_info("arnav",202341075)
# Out:
# Name of the student  arnav and the systemid  202341075

# %%
def discounted_price(price):
  for i in range(5,21,5):
    print("price after discout of ",i,"is:",((price)-price*i/100) )
discounted_price(10000)
# Out:
# price after discout of  5 is: 9500.0
# price after discout of  10 is: 9000.0
# price after discout of  15 is: 8500.0
# price after discout of  20 is: 8000.0

# %%
def discounted_price(discount):
  price=40000
  print("discounted price:",((price)-price*discount/100))

# %%
discounted_price(10)
# Out:
# discounted price: 36000.0

# %%
def factorial(number):
  if number==0 or number==1:
    return 1
  else:
    return number * factorial(number -1)

factorial(10)
# Out:
# 3628800

# %%
numbers=[1,2,3,4,5]
list2=[]
for i in numbers:
  list2.append(i*i)
print(list2)
# Out:
# [1, 4, 9, 16, 25]

# %%
def power(a, b):
    if b == 0:
        return 1
    else:
        return a * power(a, b - 1)

a = 2
b = 3
result = power(a, b)
print(f"{a} raised to the power of {b} is {result}")
# Out:
# 2 raised to the power of 3 is 8

# %%
def squares_list():
    squares = [x**2 for x in range(1, 31)]
    print(squares)

squares_list()
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169, 196, 225, 256, 289, 324, 361, 400, 441, 484, 529, 576, 625, 676, 729, 784, 841, 900]

# %%
from collections import defaultdict

def create_dict(list1, list2):
    result = defaultdict(set)
    for key, value in zip(list1, list2):
        result[key].add(value)
    return result

list1 = ['Class-V', 'Class-VI', 'Class-VII', 'Class-VIII']
list2 = [1, 2, 2, 3]

result = create_dict(list1, list2)
print(result)
# Out:
# defaultdict(<class 'set'>, {'Class-V': {1}, 'Class-VI': {2}, 'Class-VII': {2}, 'Class-VIII': {3}})
